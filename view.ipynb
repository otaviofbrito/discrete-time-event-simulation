# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('output.csv')
df.head()
# Out:
#     Time  Fila Max  Ocupacao      E[N]      E[W]    Lambda  Erro de Little
# 0  100.0        14  0.825578  3.678639  1.553342  2.190000        0.276821
# 1  200.0        18  0.864256  5.011503  2.113572  2.110000        0.551865
# 2  300.0        18  0.805019  3.918414  0.128106  1.956667        3.667753
# 3  400.0        18  0.790474  3.572195  2.129680  1.972500       -0.628599
# 4  500.0        18  0.802109  3.765579  1.648437  1.974000        0.511565

# %%
fig = px.line(df, x='Time', y="Fila Max")
fig.show()

# %%
fig = px.line(df, x='Time', y="Ocupacao")
fig.show()

# %%
fig = px.line(df, x='Time', y="E[N]")
fig.show()

# %%
fig = px.line(df, x='Time', y="E[W]")
fig.show()

# %%
fig = px.line(df, x='Time', y="Lambda")
fig.show()

# %%
fig = px.line(df, x='Time', y="Erro de Little")
fig.show()
