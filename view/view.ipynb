# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('output.csv')
df.head()
# Out:
#     Time  Fila Max  Ocupacao      E[N]      E[W]    Lambda  Erro de Little
# 0  100.0        14  0.825578  3.678639  1.679744  2.190000            -0.0
# 1  200.0        18  0.864256  5.011503  2.375120  2.110000             0.0
# 2  300.0        18  0.805019  3.922102  2.004481  1.956667            -0.0
# 3  400.0        18  0.790474  3.578466  1.814178  1.972500            -0.0
# 4  500.0        18  0.802109  3.765579  1.907588  1.974000            -0.0

# %%
fig = px.line(df, x='Time', y="Fila Max", title='Máximo de Fila')
fig.show()

# %%
fig = px.line(df, x='Time', y="Ocupacao" ,title='Utilização(Ocupação)')
fig.show()

# %%
fig = px.line(df, x='Time', y=["E[N]", "E[W]"], title='Média de elementos no sistema')
fig.show()

# %%
fig = px.line(df, x='Time', y="Lambda")
fig.show()

# %%
fig = px.line(df, x='Time', y="Erro de Little", title='Erro de little')
fig.show()
